# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix

# %%
#Loading the dataset
df=pd.read_csv("data_banknote_authentication.txt",header=None)
df.head()
# Out:
#          0       1       2        3  4
# 0  3.62160  8.6661 -2.8073 -0.44699  0
# 1  4.54590  8.1674 -2.4586 -1.46210  0
# 2  3.86600 -2.6383  1.9242  0.10645  0
# 3  3.45660  9.5228 -4.0112 -3.59440  0
# 4  0.32924 -4.4552  4.5718 -0.98880  0

# %%
#Shape of the dataset
df.shape
# Out:
# (1372, 5)

# %%
#Assigning name to the columns
df.columns=["Feature_1","Feature_2","Feature_3","Feature_4","Target"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1372 entries, 0 to 1371
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Feature_1  1372 non-null   float64
#  1   Feature_2  1372 non-null   float64
#  2   Feature_3  1372 non-null   float64
#  3   Feature_4  1372 non-null   float64
#  4   Target     1372 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 53.7 KB

# %%
df.isnull().sum()
# Out:
# Feature_1    0
# Feature_2    0
# Feature_3    0
# Feature_4    0
# Target       0
# dtype: int64

# %%
df.describe()
# Out:
#          Feature_1    Feature_2    Feature_3    Feature_4       Target
# count  1372.000000  1372.000000  1372.000000  1372.000000  1372.000000
# mean      0.433735     1.922353     1.397627    -1.191657     0.444606
# std       2.842763     5.869047     4.310030     2.101013     0.497103
# min      -7.042100   -13.773100    -5.286100    -8.548200     0.000000
# 25%      -1.773000    -1.708200    -1.574975    -2.413450     0.000000
# 50%       0.496180     2.319650     0.616630    -0.586650     0.000000
# 75%       2.821475     6.814625     3.179250     0.394810     1.000000
# max       6.824800    12.951600    17.927400     2.449500     1.000000

# %%
df["Target"].value_counts()
# Out:
# Target
# 0    762
# 1    610
# Name: count, dtype: int64

# %%
l=["Feature_1","Feature_2","Feature_3","Feature_4"]

# %%
#plotting histogram
def histogram(feature):
  plt.figure(figsize=(6,4))
  plt.hist(df[feature])
  plt.xlabel(feature)
  plt.show()

# %%
for ele in l:
  histogram(ele)

# %%
#correlation heatmap
plt.figure(figsize=(6,4))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
#Scatterplot for all combinations
def scatterplot(fea1,fea2):
  plt.figure(figsize=(6,4))
  sns.scatterplot(x=fea1,y=fea2,data=df,hue="Target")
  plt.show()

# %%
l1=l.copy()

# %%
for i in range(len(l1)):
    for j in range(i+1,len(l1)):
        scatterplot(l1[i],l1[j])

# %%
#boxplot for all features
def boxplot(feature):
  plt.figure(figsize=(6,4))
  sns.boxplot(df[feature])
  plt.show()

# %%
for ele in l:
  boxplot(ele)

# %%
X=df[l]
y=df["Target"]

# %%
#Splitting the train and test data set
x_train,x_val,y_train,y_val=train_test_split(X,y,test_size=0.2,stratify=y,random_state=42)

# %%
#Normalising the data using minmaxscaler
mm=MinMaxScaler()
x_train=mm.fit_transform(x_train)
x_val=mm.transform(x_val)

# %%
#Step activation function
def activation_fun(x):
  if x>=0:
    return 1
  else:
    return 0

# %%
#Function for forward propogation
def forward_prop(x_train,w1,w2,w3,w4,b):
  z=w1*x_train[0]+w2*x_train[1]+w3*x_train[2]+w4*x_train[3]+b
  a=activation_fun(z)
  return a

# %%
#Returns if the actual and predicted value are true or false
def error_rate(x,y):
  if x==y:
    return 1
  else:
    return 0

# %%
#Updating weights for misclassified data points
def weights_update(x_train,y_train,w1,w2,w3,w4,b,lr,mis_classified_cnt):
  a=forward_prop(x_train,w1,w2,w3,w4,b)
  error=error_rate(a,y_train)
  if error==1:
    return mis_classified_cnt,w1,w2,w3,w4,b,0
  else:
    mis_classified_cnt+=1
    #Weight updation
    w1=w1+lr*(y_train-a)*x_train[0]
    w2=w2+lr*(y_train-a)*x_train[1]
    w3=w3+lr*(y_train-a)*x_train[2]
    w4=w4+lr*(y_train-a)*x_train[3]
    b=b+lr*(y_train-a)
    return mis_classified_cnt,w1,w2,w3,w4,b,1

# %%
#Passing every data points to the forward progation and performing weight updation
def epoch_loop(x_train,y_train,w1,w2,w3,w4,b,lr):
  mis_classified_cnt=0
  mis_classified_pts=list()
  for i in range(x_train.shape[0]):
    mis_classified_cnt,w1,w2,w3,w4,b,check=weights_update(x_train[i],y_train.iloc[i],w1,w2,w3,w4,b,lr,mis_classified_cnt)
    if check==0:
      continue
    mis_classified_pts.append(i)
  return mis_classified_cnt,w1,w2,w3,w4,b,mis_classified_pts

# %%
max_epoch=100

# %%
#Initialising variables for storing best parameters
best_misclassified=float('inf')
best_lr=None
best_weights=None
best_bias=None
best_misclassified_pts=None
best_misclassified_count=None

# %%
#Performing multiple epochs until epoch reaching 100 or number of missclassified points becoming 0
def train(x_train,y_train,w1,w2,w3,w4,b,lr):
  mis_classified_cnt=0
  mis_classified_pts=list()
  mis_classified_count=list()

  w1_hist=[]
  w2_hist=[]
  w3_hist=[]
  w4_hist=[]
  b_hist =[]

  best_epoch_error=float('inf')
  best_w=None
  best_b=None
  best_pts=None
  i=1
  while(1):
    w1_prev,w2_prev,w3_prev,w4_prev,b_prev=w1,w2,w3,w4,b
    mis_classified_cnt,w1,w2,w3,w4,b,mis_classified_pts=epoch_loop(x_train,y_train,w1_prev,w2_prev,w3_prev,w4_prev,b_prev,lr)
    mis_classified_count.append(mis_classified_cnt)

    w1_hist.append(w1)
    w2_hist.append(w2)
    w3_hist.append(w3)
    w4_hist.append(w4)
    b_hist.append(b)

    if mis_classified_cnt<best_epoch_error:
      best_epoch_error=mis_classified_cnt
      best_w=[w1,w2,w3,w4]
      best_b=b
      best_pts=mis_classified_pts.copy()
    print("Epoch: ",i,"weights: ",[w1,w2,w3,w4],"\nbias: ",b,"\nMisclassified points count",mis_classified_cnt)
    i+=1
    if mis_classified_cnt==0:
      return best_w[0],best_w[1],best_w[2],best_w[3],best_b,best_epoch_error,best_pts,mis_classified_count, w1_hist, w2_hist, w3_hist, w4_hist, b_hist
    elif i>max_epoch:
      return best_w[0],best_w[1],best_w[2],best_w[3],best_b,best_epoch_error,best_pts,mis_classified_count, w1_hist, w2_hist, w3_hist, w4_hist, b_hist

# %%
w1_new=w2_new=w3_new=w4_new=b_new=0
mis_classified_cnt=0

# %%
#Performing forward propogation and weight updation for multiple learning rates
lr=[0.001,0.01,0.1]
mis_classified_count=list()
mis_classified_list=list()

weight1_histories=[]
weight2_histories=[]
weight3_histories=[]
weight4_histories=[]
bias_histories=[]

for num in lr:
  w1=w2=w3=w4=0.0
  b=0.0
  mis_classified_cnt=0
  mis_classified_pts=list()
  print("Learning rate: ",num,"\n\n")
  w1,w2,w3,w4,b,mis_classified_cnt,mis_classified_pts,mis_classified_count,w1_h,w2_h,w3_h,w4_h,b_h=train(x_train,y_train,w1,w2,w3,w4,b,num)
  mis_classified_list.append(mis_classified_count)
  weight1_histories.append(w1_h)
  weight2_histories.append(w2_h)
  weight3_histories.append(w3_h)
  weight4_histories.append(w4_h)
  bias_histories.append(b_h)

  if mis_classified_cnt<best_misclassified:
    best_misclassified=mis_classified_cnt
    best_lr=num
    best_weights=[w1,w2,w3,w4]
    best_bias=b
    best_misclassified_pts=mis_classified_pts.copy()
    best_misclassified_count=mis_classified_count.copy()
  print("Learning_rate: ",num,"\nFinal weights: ",[w1,w2,w3,w4],"\nFinal bias: ",b,"\nFinal misclassified points count",mis_classified_cnt,"\nFinal Misclassified points",mis_classified_pts)
# Out:
# Learning rate:  0.001
#
#
# Epoch:  1 weights:  [np.float64(-0.007529561336708277), np.float64(-0.005477985122377424), np.float64(-0.006564071207096559), np.float64(0.0019077793045350314)]
# bias:  0.008
# Misclassified points count 192
# Epoch:  2 weights:  [np.float64(-0.0082821989990553), np.float64(-0.007188328924178752), np.float64(-0.008476376985341998), np.float64(0.0016992768849159942)]
# bias:  0.010000000000000002
# Misclassified points count 78
# Epoch:  3 weights:  [np.float64(-0.0089162044364638), np.float64(-0.007808857723379493), np.float64(-0.009473968053405321), np.float64(0.0004676220901390015)]
# bias:  0.011000000000000003
# Misclassified points count 43
# Epoch:  4 weights:  [np.float64(-0.009461209448398691), np.float64(-0.00854227010967382), np.float64(-0.009696995217498174), np.float64(0.00025556705199607054)]
# bias:  0.012000000000000004
# Misclassified points count 39
# Epoch:  5 weights:  [np.float64(-0.009762466557053106), np.float64(-0.009681565967064182), np.float64(-0.010317536472505993), np.float64(0.0011028544016474014)]
# bias:  0.013000000000000005
# Misclassified points count 53
# Epoch:  6 weights:  [np.float64(-0.010028219191023204), np.float64(-0.010029761306955747), np.float64(-0.011339770319164059), np.float64(0.0014480722984040824)]
# bias:  0.014000000000000005
# Misclassified points count 53
# Epoch:  7 weights:  [np.float64(-0.011262917429273999), np.float64(-0.010175718043607613), np.float64(-0.012044422153893904), np.float64(0.00033589398605326137)]
# bias:  0.014000000000000005
# Misclassified points count 36
# Epoch:  8 weights:  [np.float64(-0.011551538909201013), np.float64(-0.011213583987846469), np.float64(-0.011686887665112727), np.float64(0.0008627809987363708)]
# bias:  0.015000000000000006
# Misclassified points count 45
# Epoch:  9 weights:  [np.float64(-0.01173199452653437), np.float64(-0.011680719110036809), np.float64(-0.01225327129162046), np.float64(0.00043395327373988086)]
# bias:  0.015000000000000006
# Misclassified points count 26
# Epoch:  10 weights:  [np.float64(-0.012131796587557378), np.float64(-0.01181296474796727), np.float64(-0.01237006999098696), np.float64(0.00047536810970187816)]
# bias:  0.016000000000000007
# Misclassified points count 41
# Epoch:  11 weights:  [np.float64(-0.011990858814875665), np.float64(-0.012257723566588254), np.float64(-0.012981824854347129), np.float64(0.000225792876866197)]
# bias:  0.016000000000000007
# Misclassified points count 26
# Epoch:  12 weights:  [np.float64(-0.011710566896710824), np.float64(-0.012763961092173204), np.float64(-0.013744264749640953), np.float64(0.0002554426171198595)]
# bias:  0.016000000000000007
# Misclassified points count 24
# Epoch:  13 weights:  [np.float64(-0.012469661359063619), np.float64(-0.012744065265466079), np.float64(-0.013250462164761246), np.float64(-0.0005012719427154005)]
# bias:  0.017000000000000008
# Misclassified points count 31
# Epoch:  14 weights:  [np.float64(-0.012005504986694884), np.float64(-0.01317093572612607), np.float64(-0.014415628387964783), np.float64(-0.00034380360368792826)]
# bias:  0.017000000000000008
# Misclassified points count 26
# Epoch:  15 weights:  [np.float64(-0.012827256567798085), np.float64(-0.013401366376423368), np.float64(-0.013550502701746925), np.float64(-0.0007662148921233662)]
# bias:  0.01800000000000001
# Misclassified points count 33
# Epoch:  16 weights:  [np.float64(-0.012354694567639433), np.float64(-0.013882282757149821), np.float64(-0.01434080573727716), np.float64(-0.0007049650208265066)]
# bias:  0.01800000000000001
# Misclassified points count 24
# Epoch:  17 weights:  [np.float64(-0.012143326489698434), np.float64(-0.014547792416753115), np.float64(-0.014699782307761916), np.float64(-0.00021440303271399693)]
# bias:  0.01800000000000001
# Misclassified points count 24
# Epoch:  18 weights:  [np.float64(-0.012157082988988106), np.float64(-0.014554222797636723), np.float64(-0.015562399013312462), np.float64(5.186766509102938e-05)]
# bias:  0.01800000000000001
# Misclassified points count 26
# Epoch:  19 weights:  [np.float64(-0.012499682993314954), np.float64(-0.01413308216743321), np.float64(-0.015489937426418842), np.float64(0.0009717431740534479)]
# bias:  0.01900000000000001
# Misclassified points count 33
# Epoch:  20 weights:  [np.float64(-0.013345928873792925), np.float64(-0.01431953103308933), np.float64(-0.015141308999642007), np.float64(-0.0003810747227032331)]
# bias:  0.01900000000000001
# Misclassified points count 24
# Epoch:  21 weights:  [np.float64(-0.013324476350157505), np.float64(-0.014403694746807357), np.float64(-0.015455244666583231), np.float64(-0.0005283707399260535)]
# bias:  0.01900000000000001
# Misclassified points count 20
# Epoch:  22 weights:  [np.float64(-0.013349428574519111), np.float64(-0.015444501042107216), np.float64(-0.015380712243463346), np.float64(0.00024226837646838665)]
# bias:  0.01900000000000001
# Misclassified points count 26
# Epoch:  23 weights:  [np.float64(-0.013114958000706651), np.float64(-0.015871059619004247), np.float64(-0.015742166745009355), np.float64(0.00045384632377030076)]
# bias:  0.01900000000000001
# Misclassified points count 22
# Epoch:  24 weights:  [np.float64(-0.01334991173946585), np.float64(-0.014725571737007444), np.float64(-0.01617260312134783), np.float64(0.0003552054289324664)]
# bias:  0.02000000000000001
# Misclassified points count 27
# Epoch:  25 weights:  [np.float64(-0.014088635390750563), np.float64(-0.01570211216589907), np.float64(-0.015419881321505666), np.float64(-0.0007522622548790188)]
# bias:  0.02000000000000001
# Misclassified points count 28
# Epoch:  26 weights:  [np.float64(-0.013595685993264463), np.float64(-0.015756314832346217), np.float64(-0.01628781527209367), np.float64(-0.00044143593391678755)]
# bias:  0.02000000000000001
# Misclassified points count 22
# Epoch:  27 weights:  [np.float64(-0.01382451291204227), np.float64(-0.01639580751140342), np.float64(-0.0162433651735543), np.float64(-0.00011427695043759079)]
# bias:  0.02000000000000001
# Misclassified points count 26
# Epoch:  28 weights:  [np.float64(-0.014199845538656723), np.float64(-0.016219964938802046), np.float64(-0.01687078844437155), np.float64(-5.762791220105805e-05)]
# bias:  0.02000000000000001
# Misclassified points count 28
# Epoch:  29 weights:  [np.float64(-0.014528676567942284), np.float64(-0.016269907463881836), np.float64(-0.016334629021894222), np.float64(-0.0002925610333692145)]
# bias:  0.02100000000000001
# Misclassified points count 33
# Epoch:  30 weights:  [np.float64(-0.014723487953327626), np.float64(-0.016069053422489418), np.float64(-0.017080328004588377), np.float64(-0.0008533145317545754)]
# bias:  0.02100000000000001
# Misclassified points count 22
# Epoch:  31 weights:  [np.float64(-0.015260643337732213), np.float64(-0.01684179137651697), np.float64(-0.016547790604906635), np.float64(-9.562276407544404e-05)]
# bias:  0.02100000000000001
# Misclassified points count 28
# Epoch:  32 weights:  [np.float64(-0.014805791856867706), np.float64(-0.01700369964863976), np.float64(-0.017103085209606336), np.float64(0.0001499665091028215)]
# bias:  0.02100000000000001
# Misclassified points count 20
# Epoch:  33 weights:  [np.float64(-0.014597738867374742), np.float64(-0.01749847152634091), np.float64(-0.017197054686118603), np.float64(0.0001229756353255013)]
# bias:  0.02100000000000001
# Misclassified points count 20
# Epoch:  34 weights:  [np.float64(-0.014480358630984487), np.float64(-0.016491656856765572), np.float64(-0.017628896919620267), np.float64(0.0003903468151822896)]
# bias:  0.022000000000000013
# Misclassified points count 27
# Epoch:  35 weights:  [np.float64(-0.015394247604006572), np.float64(-0.017172184945013512), np.float64(-0.017001512029566054), np.float64(-0.0008365873356109899)]
# bias:  0.022000000000000013
# Misclassified points count 28
# Epoch:  36 weights:  [np.float64(-0.01508814602398508), np.float64(-0.017249459900391863), np.float64(-0.017433759632924584), np.float64(-0.0007297072869378023)]
# bias:  0.022000000000000013
# Misclassified points count 18
# Epoch:  37 weights:  [np.float64(-0.015097789130952027), np.float64(-0.017536413542528162), np.float64(-0.01735904479336911), np.float64(-0.0006116960546637348)]
# bias:  0.022000000000000013
# Misclassified points count 18
# Epoch:  38 weights:  [np.float64(-0.015069067498864105), np.float64(-0.017673696655154305), np.float64(-0.017590910314075316), np.float64(-0.0004142820049609224)]
# bias:  0.022000000000000013
# Misclassified points count 22
# Epoch:  39 weights:  [np.float64(-0.01493868651969789), np.float64(-0.01779905447020929), np.float64(-0.0180002847076377), np.float64(5.718275845929149e-06)]
# bias:  0.022000000000000013
# Misclassified points count 20
# Epoch:  40 weights:  [np.float64(-0.01535751985663693), np.float64(-0.01808314185004891), np.float64(-0.017864859263348024), np.float64(8.706268544952315e-05)]
# bias:  0.022000000000000013
# Misclassified points count 24
# Epoch:  41 weights:  [np.float64(-0.015552388212217485), np.float64(-0.01819735267374384), np.float64(-0.01774085317417528), np.float64(0.00010315975101792289)]
# bias:  0.022000000000000013
# Misclassified points count 16
# Epoch:  42 weights:  [np.float64(-0.015038726903633734), np.float64(-0.017232507904672525), np.float64(-0.018347398603630143), np.float64(0.0004968924228951166)]
# bias:  0.023000000000000013
# Misclassified points count 25
# Epoch:  43 weights:  [np.float64(-0.015644497263267106), np.float64(-0.017747957993915802), np.float64(-0.017925316296299412), np.float64(-0.0007252117564468593)]
# bias:  0.023000000000000013
# Misclassified points count 24
# Epoch:  44 weights:  [np.float64(-0.015686317713403758), np.float64(-0.01805899048445826), np.float64(-0.018103271938487202), np.float64(-0.0006375716572284385)]
# bias:  0.023000000000000013
# Misclassified points count 22
# Epoch:  45 weights:  [np.float64(-0.015760373919188754), np.float64(-0.018431807765849628), np.float64(-0.01839636555736191), np.float64(-0.0005105964150325293)]
# bias:  0.023000000000000013
# Misclassified points count 26
# Epoch:  46 weights:  [np.float64(-0.015731652287100828), np.float64(-0.01856909087847577), np.float64(-0.018628231078068117), np.float64(-0.00031318236532971685)]
# bias:  0.023000000000000013
# Misclassified points count 22
# Epoch:  47 weights:  [np.float64(-0.015741295394067774), np.float64(-0.01885604452061207), np.float64(-0.018553516238512643), np.float64(-0.00019517113305564946)]
# bias:  0.023000000000000013
# Misclassified points count 18
# Epoch:  48 weights:  [np.float64(-0.015936163749648326), np.float64(-0.018970255344306998), np.float64(-0.018429510149339898), np.float64(-0.00017907406748724972)]
# bias:  0.023000000000000013
# Misclassified points count 16
# Epoch:  49 weights:  [np.float64(-0.016095227419250034), np.float64(-0.01899673833569698), np.float64(-0.018495540586578724), np.float64(-0.00013307884120372854)]
# bias:  0.023000000000000013
# Misclassified points count 18
# Epoch:  50 weights:  [np.float64(-0.0156193034564321), np.float64(-0.0180278673287259), np.float64(-0.019104082678200938), np.float64(0.00024891301539757234)]
# bias:  0.024000000000000014
# Misclassified points count 25
# Epoch:  51 weights:  [np.float64(-0.01653161312910588), np.float64(-0.018431351708344746), np.float64(-0.018604729976238337), np.float64(-0.0011828238685823965)]
# bias:  0.024000000000000014
# Misclassified points count 26
# Epoch:  52 weights:  [np.float64(-0.01650058384354098), np.float64(-0.01822863848799054), np.float64(-0.018929084510990176), np.float64(-0.0009969107315018519)]
# bias:  0.024000000000000014
# Misclassified points count 16
# Epoch:  53 weights:  [np.float64(-0.016331585725720854), np.float64(-0.01829383472966958), np.float64(-0.01930842272313661), np.float64(-0.0010890188421397518)]
# bias:  0.024000000000000014
# Misclassified points count 20
# Epoch:  54 weights:  [np.float64(-0.016712883636573323), np.float64(-0.018674862393216786), np.float64(-0.018908540884137442), np.float64(-0.0009330032105583411)]
# bias:  0.024000000000000014
# Misclassified points count 20
# Epoch:  55 weights:  [np.float64(-0.01664898471179562), np.float64(-0.018878114440947905), np.float64(-0.01902186590882619), np.float64(-0.0007733530022932592)]
# bias:  0.024000000000000014
# Misclassified points count 20
# Epoch:  56 weights:  [np.float64(-0.01658508578701792), np.float64(-0.019081366488679023), np.float64(-0.01913519093351494), np.float64(-0.0006137027940281775)]
# bias:  0.024000000000000014
# Misclassified points count 20
# Epoch:  57 weights:  [np.float64(-0.016556364154930003), np.float64(-0.019218649601305166), np.float64(-0.019367056454221144), np.float64(-0.000416288744325365)]
# bias:  0.024000000000000014
# Misclassified points count 22
# Epoch:  58 weights:  [np.float64(-0.016998980745516225), np.float64(-0.01970699783346493), np.float64(-0.018866410018672793), np.float64(-7.6896878363836e-05)]
# bias:  0.024000000000000014
# Misclassified points count 22
# Epoch:  59 weights:  [np.float64(-0.01699922016456447), np.float64(-0.01962267696176197), np.float64(-0.01916190135712643), np.float64(-0.0002329053961716706)]
# bias:  0.024000000000000014
# Misclassified points count 18
# Epoch:  60 weights:  [np.float64(-0.01652329620174654), np.float64(-0.01865380595479089), np.float64(-0.019770443448748645), np.float64(0.00014908646042963028)]
# bias:  0.025000000000000015
# Misclassified points count 25
# Epoch:  61 weights:  [np.float64(-0.017014322314287917), np.float64(-0.01914169019670941), np.float64(-0.019449456502520526), np.float64(0.0002959091309027899)]
# bias:  0.025000000000000015
# Misclassified points count 24
# Epoch:  62 weights:  [np.float64(-0.017288329482436533), np.float64(-0.019052951539212777), np.float64(-0.02006084308305328), np.float64(-0.0008544096784761587)]
# bias:  0.025000000000000015
# Misclassified points count 26
# Epoch:  63 weights:  [np.float64(-0.01738266563543396), np.float64(-0.01968732685493194), np.float64(-0.019772187832866765), np.float64(-0.0006896780830252297)]
# bias:  0.025000000000000015
# Misclassified points count 22
# Epoch:  64 weights:  [np.float64(-0.017353944003346045), np.float64(-0.019824609967558086), np.float64(-0.02000405335357297), np.float64(-0.0004922640333224172)]
# bias:  0.025000000000000015
# Misclassified points count 22
# Epoch:  65 weights:  [np.float64(-0.017592722677743356), np.float64(-0.020336651636875234), np.float64(-0.01951574913643272), np.float64(-0.0002850451443815272)]
# bias:  0.025000000000000015
# Misclassified points count 16
# Epoch:  66 weights:  [np.float64(-0.01757569363736664), np.float64(-0.020119305511380838), np.float64(-0.020015654693880957), np.float64(-0.0002703942340993165)]
# bias:  0.025000000000000015
# Misclassified points count 20
# Epoch:  67 weights:  [np.float64(-0.017697019961202543), np.float64(-0.02014981474067059), np.float64(-0.020079688468952434), np.float64(-0.00021265819253990254)]
# bias:  0.025000000000000015
# Misclassified points count 18
# Epoch:  68 weights:  [np.float64(-0.017818346285038447), np.float64(-0.02018032396996034), np.float64(-0.02014372224402391), np.float64(-0.00015492215098048847)]
# bias:  0.025000000000000015
# Misclassified points count 18
# Epoch:  69 weights:  [np.float64(-0.01734483237782054), np.float64(-0.01967137943550345), np.float64(-0.02131739131559756), np.float64(-0.00046876873683718355)]
# bias:  0.025000000000000015
# Misclassified points count 16
# Epoch:  70 weights:  [np.float64(-0.01773398207962845), np.float64(-0.02006913207631887), np.float64(-0.019934293513650916), np.float64(-5.615582908223408e-05)]
# bias:  0.026000000000000016
# Misclassified points count 23
# Epoch:  71 weights:  [np.float64(-0.018020820522250812), np.float64(-0.01969444835676355), np.float64(-0.02054439498548849), np.float64(-0.0011252652033509661)]
# bias:  0.026000000000000016
# Misclassified points count 22
# Epoch:  72 weights:  [np.float64(-0.01846648033085981), np.float64(-0.02026672643659232), np.float64(-0.01995861225510688), np.float64(-0.0008490548790190529)]
# bias:  0.026000000000000016
# Misclassified points count 22
# Epoch:  73 weights:  [np.float64(-0.018768591833791252), np.float64(-0.020402376228732172), np.float64(-0.019960978062590697), np.float64(-0.0006949686713155854)]
# bias:  0.026000000000000016
# Misclassified points count 22
# Epoch:  74 weights:  [np.float64(-0.018396155312290417), np.float64(-0.020475618959239897), np.float64(-0.02066245162514487), np.float64(1.9756184770903227e-05)]
# bias:  0.026000000000000016
# Misclassified points count 24
# Epoch:  75 weights:  [np.float64(-0.01847280907052045), np.float64(-0.02026942019929123), np.float64(-0.021022319146825688), np.float64(-0.0005026297374455993)]
# bias:  0.026000000000000016
# Misclassified points count 18
# Epoch:  76 weights:  [np.float64(-0.01896928773554292), np.float64(-0.020724084236679863), np.float64(-0.020529068554942576), np.float64(-2.054521458324176e-05)]
# bias:  0.026000000000000016
# Misclassified points count 22
# Epoch:  77 weights:  [np.float64(-0.018969527154591163), np.float64(-0.020639763364976905), np.float64(-0.020824559893396214), np.float64(-0.00017655373239107647)]
# bias:  0.026000000000000016
# Misclassified points count 18
# Epoch:  78 weights:  [np.float64(-0.019005917407639794), np.float64(-0.020770311135391538), np.float64(-0.020966230620948857), np.float64(-7.08898581925462e-05)]
# bias:  0.026000000000000016
# Misclassified points count 22
# Epoch:  79 weights:  [np.float64(-0.01820212636566214), np.float64(-0.02004061587220804), np.float64(-0.02153220456515444), np.float64(0.00038663370618242465)]
# bias:  0.027000000000000017
# Misclassified points count 19
# Epoch:  80 weights:  [np.float64(-0.018817206664791725), np.float64(-0.020419399506823206), np.float64(-0.021225954538201648), np.float64(-0.00016165664810221993)]
# bias:  0.027000000000000017
# Misclassified points count 24
# Epoch:  81 weights:  [np.float64(-0.019107189285276483), np.float64(-0.020645800177363942), np.float64(-0.02102627797159808), np.float64(-0.00027361312304020847)]
# bias:  0.027000000000000017
# Misclassified points count 20
# Epoch:  82 weights:  [np.float64(-0.019268055088015382), np.float64(-0.020350168795159457), np.float64(-0.021384301491674664), np.float64(-0.0008353391491552457)]
# bias:  0.027000000000000017
# Misclassified points count 16
# Epoch:  83 weights:  [np.float64(-0.01939881394543846), np.float64(-0.02064826942865581), np.float64(-0.02122212163683157), np.float64(-0.0008783023166565331)]
# bias:  0.027000000000000017
# Misclassified points count 20
# Epoch:  84 weights:  [np.float64(-0.019564050588091113), np.float64(-0.021076609503567777), np.float64(-0.020921857283935544), np.float64(-0.0006294444517246289)]
# bias:  0.027000000000000017
# Misclassified points count 18
# Epoch:  85 weights:  [np.float64(-0.019191614066590278), np.float64(-0.021149852234075506), np.float64(-0.021623330846489718), np.float64(8.528040436185972e-05)]
# bias:  0.027000000000000017
# Misclassified points count 24
# Epoch:  86 weights:  [np.float64(-0.019253376248476645), np.float64(-0.02079731282296892), np.float64(-0.022104912823918375), np.float64(-0.0008171607432021413)]
# bias:  0.027000000000000017
# Misclassified points count 18
# Epoch:  87 weights:  [np.float64(-0.019642300232928834), np.float64(-0.021310510726032374), np.float64(-0.021787319772130217), np.float64(-0.00038118161651145026)]
# bias:  0.027000000000000017
# Misclassified points count 26
# Epoch:  88 weights:  [np.float64(-0.019391389791517995), np.float64(-0.02166800211040713), np.float64(-0.021940996347358667), np.float64(-0.0002065244348762184)]
# bias:  0.027000000000000017
# Misclassified points count 16
# Epoch:  89 weights:  [np.float64(-0.019193972199987086), np.float64(-0.021628047312037078), np.float64(-0.02249452284949117), np.float64(-0.0001451500725417774)]
# bias:  0.027000000000000017
# Misclassified points count 18
# Epoch:  90 weights:  [np.float64(-0.01896428712257253), np.float64(-0.021521040685208714), np.float64(-0.022093976893917983), np.float64(0.0003063180792811269)]
# bias:  0.028000000000000018
# Misclassified points count 25
# Epoch:  91 weights:  [np.float64(-0.019814003353309035), np.float64(-0.02145684501603375), np.float64(-0.021903166714822123), np.float64(-0.0006237160855524953)]
# bias:  0.028000000000000018
# Misclassified points count 22
# Epoch:  92 weights:  [np.float64(-0.020325671426202042), np.float64(-0.021488583445277105), np.float64(-0.02168146649014372), np.float64(-0.0009247288622642476)]
# bias:  0.028000000000000018
# Misclassified points count 18
# Epoch:  93 weights:  [np.float64(-0.019953234904701207), np.float64(-0.02156182617578483), np.float64(-0.022382940052697895), np.float64(-0.000210004006177759)]
# bias:  0.028000000000000018
# Misclassified points count 24
# Epoch:  94 weights:  [np.float64(-0.020216965082318416), np.float64(-0.0215883840043105), np.float64(-0.022269870324770062), np.float64(-0.0006032456404736362)]
# bias:  0.028000000000000018
# Misclassified points count 18
# Epoch:  95 weights:  [np.float64(-0.02038220172497107), np.float64(-0.022016724079222467), np.float64(-0.021969605971874036), np.float64(-0.000354387775541732)]
# bias:  0.028000000000000018
# Misclassified points count 18
# Epoch:  96 weights:  [np.float64(-0.02027205598223117), np.float64(-0.022166707053774097), np.float64(-0.022081563951407167), np.float64(-0.00045108988627323395)]
# bias:  0.028000000000000018
# Misclassified points count 16
# Epoch:  97 weights:  [np.float64(-0.02019366932046827), np.float64(-0.02247557338342419), np.float64(-0.02216551691125399), np.float64(-0.00010213963588712475)]
# bias:  0.028000000000000018
# Misclassified points count 20
# Epoch:  98 weights:  [np.float64(-0.020193908739516514), np.float64(-0.022391252511721232), np.float64(-0.022461008249707627), np.float64(-0.00025814815369495925)]
# bias:  0.028000000000000018
# Misclassified points count 18
# Epoch:  99 weights:  [np.float64(-0.02024360694171023), np.float64(-0.022049946154680738), np.float64(-0.023191711566409298), np.float64(-0.00025911600131044133)]
# bias:  0.028000000000000018
# Misclassified points count 24
# Epoch:  100 weights:  [np.float64(-0.020013921864295674), np.float64(-0.021942939527852375), np.float64(-0.02279116561083611), np.float64(0.00019235215051246297)]
# bias:  0.02900000000000002
# Misclassified points count 25
# Learning_rate:  0.001
# Final weights:  [np.float64(-0.015552388212217485), np.float64(-0.01819735267374384), np.float64(-0.01774085317417528), np.float64(0.00010315975101792289)]
# Final bias:  0.022000000000000013
# Final misclassified points count 16
# Final Misclassified points [156, 179, 200, 316, 357, 438, 446, 456, 690, 698, 780, 789, 868, 874, 968, 1010]
# Learning rate:  0.01
#
#
# Epoch:  1 weights:  [np.float64(-0.07529561336708274), np.float64(-0.054779851223774254), np.float64(-0.0656407120709656), np.float64(0.0190777930453503)]
# bias:  0.08
# Misclassified points count 192
# Epoch:  2 weights:  [np.float64(-0.08282198999055301), np.float64(-0.07188328924178757), np.float64(-0.08476376985342005), np.float64(0.01699276884915991)]
# bias:  0.09999999999999999
# Misclassified points count 78
# Epoch:  3 weights:  [np.float64(-0.0891620443646381), np.float64(-0.07808857723379496), np.float64(-0.09473968053405335), np.float64(0.004676220901389985)]
# bias:  0.10999999999999999
# Misclassified points count 43
# Epoch:  4 weights:  [np.float64(-0.09461209448398705), np.float64(-0.08542270109673823), np.float64(-0.09696995217498194), np.float64(0.002555670519960674)]
# bias:  0.11999999999999998
# Misclassified points count 39
# Epoch:  5 weights:  [np.float64(-0.09762466557053126), np.float64(-0.0968156596706418), np.float64(-0.1031753647250603), np.float64(0.011028544016473987)]
# bias:  0.12999999999999998
# Misclassified points count 53
# Epoch:  6 weights:  [np.float64(-0.10028219191023226), np.float64(-0.10029761306955745), np.float64(-0.1133977031916411), np.float64(0.014480722984040793)]
# bias:  0.13999999999999999
# Misclassified points count 53
# Epoch:  7 weights:  [np.float64(-0.11262917429274022), np.float64(-0.10175718043607608), np.float64(-0.12044422153893962), np.float64(0.0033589398605325792)]
# bias:  0.13999999999999999
# Misclassified points count 36
# Epoch:  8 weights:  [np.float64(-0.1155153890920104), np.float64(-0.11213583987846462), np.float64(-0.11686887665112795), np.float64(0.00862780998736368)]
# bias:  0.15
# Misclassified points count 45
# Epoch:  9 weights:  [np.float64(-0.11731994526534403), np.float64(-0.11680719110036793), np.float64(-0.12253271291620536), np.float64(0.004339532737398779)]
# bias:  0.15
# Misclassified points count 26
# Epoch:  10 weights:  [np.float64(-0.1213179658755742), np.float64(-0.11812964747967247), np.float64(-0.12370069990987036), np.float64(0.004753681097018753)]
# bias:  0.16
# Misclassified points count 41
# Epoch:  11 weights:  [np.float64(-0.1199085881487571), np.float64(-0.12257723566588224), np.float64(-0.1298182485434721), np.float64(0.0022579287686619407)]
# bias:  0.16
# Misclassified points count 26
# Epoch:  12 weights:  [np.float64(-0.11710566896710872), np.float64(-0.1276396109217317), np.float64(-0.13744264749641036), np.float64(0.002554426171198559)]
# bias:  0.16
# Misclassified points count 24
# Epoch:  13 weights:  [np.float64(-0.12469661359063666), np.float64(-0.12744065265466037), np.float64(-0.13250462164761337), np.float64(-0.005012719427154042)]
# bias:  0.17
# Misclassified points count 31
# Epoch:  14 weights:  [np.float64(-0.12005504986694931), np.float64(-0.13170935726126026), np.float64(-0.14415628387964877), np.float64(-0.0034380360368793175)]
# bias:  0.17
# Misclassified points count 26
# Epoch:  15 weights:  [np.float64(-0.12827256567798134), np.float64(-0.13401366376423315), np.float64(-0.13550502701747022), np.float64(-0.007662148921233694)]
# bias:  0.18000000000000002
# Misclassified points count 33
# Epoch:  16 weights:  [np.float64(-0.12354694567639482), np.float64(-0.13882282757149758), np.float64(-0.14340805737277262), np.float64(-0.007049650208265097)]
# bias:  0.18000000000000002
# Misclassified points count 24
# Epoch:  17 weights:  [np.float64(-0.12143326489698489), np.float64(-0.14547792416753044), np.float64(-0.14699782307762024), np.float64(-0.0021440303271399964)]
# bias:  0.18000000000000002
# Misclassified points count 24
# Epoch:  18 weights:  [np.float64(-0.12157082988988163), np.float64(-0.14554222797636648), np.float64(-0.15562399013312572), np.float64(0.0005186766509102658)]
# bias:  0.18000000000000002
# Misclassified points count 26
# Epoch:  19 weights:  [np.float64(-0.12499682993315013), np.float64(-0.14133082167433128), np.float64(-0.15489937426418954), np.float64(0.00971743174053445)]
# bias:  0.19000000000000003
# Misclassified points count 33
# Epoch:  20 weights:  [np.float64(-0.13345928873792992), np.float64(-0.1431953103308924), np.float64(-0.15141308999642125), np.float64(-0.0038107472270323605)]
# bias:  0.19000000000000003
# Misclassified points count 24
# Epoch:  21 weights:  [np.float64(-0.1332447635015758), np.float64(-0.14403694746807258), np.float64(-0.15455244666583354), np.float64(-0.0052837073992605624)]
# bias:  0.19000000000000003
# Misclassified points count 20
# Epoch:  22 weights:  [np.float64(-0.1334942857451919), np.float64(-0.1544450104210711), np.float64(-0.15380712243463474), np.float64(0.002422683764683837)]
# bias:  0.19000000000000003
# Misclassified points count 26
# Epoch:  23 weights:  [np.float64(-0.13114958000706736), np.float64(-0.15871059619004138), np.float64(-0.1574216674500949), np.float64(0.004538463237702978)]
# bias:  0.19000000000000003
# Misclassified points count 22
# Epoch:  24 weights:  [np.float64(-0.13349911739465942), np.float64(-0.14725571737007334), np.float64(-0.16172603121347967), np.float64(0.003552054289324636)]
# bias:  0.20000000000000004
# Misclassified points count 27
# Epoch:  25 weights:  [np.float64(-0.14088635390750662), np.float64(-0.15702112165898957), np.float64(-0.15419881321505807), np.float64(-0.007522622548790216)]
# bias:  0.20000000000000004
# Misclassified points count 28
# Epoch:  26 weights:  [np.float64(-0.13595685993264567), np.float64(-0.157563148323461), np.float64(-0.16287815272093809), np.float64(-0.004414359339167901)]
# bias:  0.20000000000000004
# Misclassified points count 22
# Epoch:  27 weights:  [np.float64(-0.13824512912042383), np.float64(-0.16395807511403301), np.float64(-0.16243365173554433), np.float64(-0.0011427695043759335)]
# bias:  0.20000000000000004
# Misclassified points count 26
# Epoch:  28 weights:  [np.float64(-0.1419984553865684), np.float64(-0.16219964938801926), np.float64(-0.1687078844437168), np.float64(-0.0005762791220106063)]
# bias:  0.20000000000000004
# Misclassified points count 28
# Epoch:  29 weights:  [np.float64(-0.14528676567942417), np.float64(-0.16269907463881714), np.float64(-0.16334629021894354), np.float64(-0.0029256103336921697)]
# bias:  0.21000000000000005
# Misclassified points count 33
# Epoch:  30 weights:  [np.float64(-0.1472348795332776), np.float64(-0.16069053422489293), np.float64(-0.17080328004588513), np.float64(-0.008533145317545777)]
# bias:  0.21000000000000005
# Misclassified points count 22
# Epoch:  31 weights:  [np.float64(-0.15260643337732352), np.float64(-0.16841791376516835), np.float64(-0.16547790604906773), np.float64(-0.0009562276407544656)]
# bias:  0.21000000000000005
# Misclassified points count 28
# Epoch:  32 weights:  [np.float64(-0.1480579185686785), np.float64(-0.17003699648639622), np.float64(-0.17103085209606475), np.float64(0.0014996650910281874)]
# bias:  0.21000000000000005
# Misclassified points count 20
# Epoch:  33 weights:  [np.float64(-0.1459773886737489), np.float64(-0.17498471526340773), np.float64(-0.17197054686118743), np.float64(0.0012297563532549845)]
# bias:  0.21000000000000005
# Misclassified points count 20
# Epoch:  34 weights:  [np.float64(-0.1448035863098464), np.float64(-0.16491656856765433), np.float64(-0.17628896919620404), np.float64(0.003903468151822867)]
# bias:  0.22000000000000006
# Misclassified points count 27
# Epoch:  35 weights:  [np.float64(-0.15394247604006736), np.float64(-0.1717218494501338), np.float64(-0.17001512029566201), np.float64(-0.008365873356109927)]
# bias:  0.22000000000000006
# Misclassified points count 28
# Epoch:  36 weights:  [np.float64(-0.1508814602398525), np.float64(-0.17249459900391736), np.float64(-0.17433759632924736), np.float64(-0.007297072869378051)]
# bias:  0.22000000000000006
# Misclassified points count 18
# Epoch:  37 weights:  [np.float64(-0.15097789130952205), np.float64(-0.17536413542528037), np.float64(-0.17359044793369266), np.float64(-0.00611696054663738)]
# bias:  0.22000000000000006
# Misclassified points count 18
# Epoch:  38 weights:  [np.float64(-0.1506906749886429), np.float64(-0.17673696655154184), np.float64(-0.17590910314075472), np.float64(-0.0041428200496092535)]
# bias:  0.22000000000000006
# Misclassified points count 22
# Epoch:  39 weights:  [np.float64(-0.14938686519698077), np.float64(-0.17799054470209166), np.float64(-0.18000284707637856), np.float64(5.7182758459263516e-05)]
# bias:  0.22000000000000006
# Misclassified points count 20
# Epoch:  40 weights:  [np.float64(-0.15357519856637125), np.float64(-0.18083141850048787), np.float64(-0.17864859263348182), np.float64(0.0008706268544952066)]
# bias:  0.22000000000000006
# Misclassified points count 24
# Epoch:  41 weights:  [np.float64(-0.15552388212217685), np.float64(-0.18197352673743716), np.float64(-0.1774085317417544), np.float64(0.0010315975101792031)]
# bias:  0.22000000000000006
# Misclassified points count 16
# Epoch:  42 weights:  [np.float64(-0.15038726903633942), np.float64(-0.17232507904672406), np.float64(-0.18347398603630305), np.float64(0.004968924228951141)]
# bias:  0.23000000000000007
# Misclassified points count 25
# Epoch:  43 weights:  [np.float64(-0.15644497263267318), np.float64(-0.17747957993915683), np.float64(-0.17925316296299582), np.float64(-0.007252117564468618)]
# bias:  0.23000000000000007
# Misclassified points count 24
# Epoch:  44 weights:  [np.float64(-0.1568631771340398), np.float64(-0.1805899048445814), np.float64(-0.18103271938487375), np.float64(-0.006375716572284408)]
# bias:  0.23000000000000007
# Misclassified points count 22
# Epoch:  45 weights:  [np.float64(-0.15760373919188983), np.float64(-0.18431807765849512), np.float64(-0.1839636555736209), np.float64(-0.00510596415032531)]
# bias:  0.23000000000000007
# Misclassified points count 26
# Epoch:  46 weights:  [np.float64(-0.15731652287101067), np.float64(-0.18569090878475655), np.float64(-0.18628231078068297), np.float64(-0.0031318236532971826)]
# bias:  0.23000000000000007
# Misclassified points count 22
# Epoch:  47 weights:  [np.float64(-0.15741295394068022), np.float64(-0.18856044520611956), np.float64(-0.18553516238512827), np.float64(-0.0019517113305565102)]
# bias:  0.23000000000000007
# Misclassified points count 18
# Epoch:  48 weights:  [np.float64(-0.15936163749648583), np.float64(-0.18970255344306886), np.float64(-0.18429510149340084), np.float64(-0.0017907406748725136)]
# bias:  0.23000000000000007
# Misclassified points count 16
# Epoch:  49 weights:  [np.float64(-0.160952274192503), np.float64(-0.18996738335696867), np.float64(-0.1849554058657891), np.float64(-0.0013307884120373013)]
# bias:  0.23000000000000007
# Misclassified points count 18
# Epoch:  50 weights:  [np.float64(-0.1561930345643237), np.float64(-0.18027867328725786), np.float64(-0.19104082678201123), np.float64(0.0024891301539757098)]
# bias:  0.24000000000000007
# Misclassified points count 25
# Epoch:  51 weights:  [np.float64(-0.16531613129106154), np.float64(-0.18431351708344632), np.float64(-0.18604729976238538), np.float64(-0.011828238685823984)]
# bias:  0.24000000000000005
# Misclassified points count 26
# Epoch:  52 weights:  [np.float64(-0.16500583843541253), np.float64(-0.18228638487990426), np.float64(-0.18929084510990382), np.float64(-0.00996910731501854)]
# bias:  0.24000000000000005
# Misclassified points count 16
# Epoch:  53 weights:  [np.float64(-0.16331585725721126), np.float64(-0.1829383472966947), np.float64(-0.19308422723136817), np.float64(-0.010890188421397537)]
# bias:  0.24000000000000005
# Misclassified points count 20
# Epoch:  54 weights:  [np.float64(-0.16712883636573594), np.float64(-0.1867486239321667), np.float64(-0.1890854088413765), np.float64(-0.009330032105583435)]
# bias:  0.24000000000000005
# Misclassified points count 20
# Epoch:  55 weights:  [np.float64(-0.16648984711795892), np.float64(-0.18878114440947794), np.float64(-0.19021865908826402), np.float64(-0.007733530022932617)]
# bias:  0.24000000000000005
# Misclassified points count 20
# Epoch:  56 weights:  [np.float64(-0.1658508578701819), np.float64(-0.19081366488678916), np.float64(-0.19135190933515153), np.float64(-0.006137027940281801)]
# bias:  0.24000000000000005
# Misclassified points count 20
# Epoch:  57 weights:  [np.float64(-0.16556364154930273), np.float64(-0.19218649601305063), np.float64(-0.1936705645422136), np.float64(-0.004162887443253675)]
# bias:  0.24000000000000005
# Misclassified points count 22
# Epoch:  58 weights:  [np.float64(-0.16998980745516493), np.float64(-0.19706997833464826), np.float64(-0.18866410018673008), np.float64(-0.0007689687836383843)]
# bias:  0.24000000000000005
# Misclassified points count 22
# Epoch:  59 weights:  [np.float64(-0.16999220164564732), np.float64(-0.19622676961761865), np.float64(-0.1916190135712665), np.float64(-0.0023290539617167316)]
# bias:  0.24000000000000005
# Misclassified points count 18
# Epoch:  60 weights:  [np.float64(-0.165232962017468), np.float64(-0.18653805954790784), np.float64(-0.19770443448748865), np.float64(0.0014908646042962794)]
# bias:  0.25000000000000006
# Misclassified points count 25
# Epoch:  61 weights:  [np.float64(-0.17014322314288177), np.float64(-0.19141690196709304), np.float64(-0.19449456502520746), np.float64(0.0029590913090278767)]
# bias:  0.25000000000000006
# Misclassified points count 24
# Epoch:  62 weights:  [np.float64(-0.17288329482436796), np.float64(-0.19052951539212679), np.float64(-0.2006084308305351), np.float64(-0.008544096784761613)]
# bias:  0.25000000000000006
# Misclassified points count 26
# Epoch:  63 weights:  [np.float64(-0.17382665635434225), np.float64(-0.1968732685493184), np.float64(-0.19772187832867), np.float64(-0.0068967808302523225)]
# bias:  0.25000000000000006
# Misclassified points count 22
# Epoch:  64 weights:  [np.float64(-0.17353944003346308), np.float64(-0.19824609967557985), np.float64(-0.20004053353573206), np.float64(-0.004922640333224198)]
# bias:  0.25000000000000006
# Misclassified points count 22
# Epoch:  65 weights:  [np.float64(-0.17592722677743616), np.float64(-0.20336651636875133), np.float64(-0.1951574913643296), np.float64(-0.0028504514438153)]
# bias:  0.25000000000000006
# Misclassified points count 16
# Epoch:  66 weights:  [np.float64(-0.17575693637366896), np.float64(-0.20119305511380736), np.float64(-0.20015654693881202), np.float64(-0.002703942340993193)]
# bias:  0.25000000000000006
# Misclassified points count 20
# Epoch:  67 weights:  [np.float64(-0.17697019961202798), np.float64(-0.2014981474067049), np.float64(-0.2007968846895268), np.float64(-0.002126581925399054)]
# bias:  0.25000000000000006
# Misclassified points count 18
# Epoch:  68 weights:  [np.float64(-0.178183462850387), np.float64(-0.20180323969960245), np.float64(-0.2014372224402416), np.float64(-0.0015492215098049152)]
# bias:  0.25000000000000006
# Misclassified points count 18
# Epoch:  69 weights:  [np.float64(-0.17344832377820793), np.float64(-0.19671379435503356), np.float64(-0.2131739131559781), np.float64(-0.004687687368371865)]
# bias:  0.25000000000000006
# Misclassified points count 16
# Epoch:  70 weights:  [np.float64(-0.17733982079628696), np.float64(-0.20069132076318774), np.float64(-0.1993429351365118), np.float64(-0.0005615582908223716)]
# bias:  0.26000000000000006
# Misclassified points count 23
# Epoch:  71 weights:  [np.float64(-0.1802082052225106), np.float64(-0.19694448356763453), np.float64(-0.2054439498548876), np.float64(-0.011252652033509693)]
# bias:  0.26000000000000006
# Misclassified points count 22
# Epoch:  72 weights:  [np.float64(-0.18466480330860055), np.float64(-0.20266726436592225), np.float64(-0.19958612255107153), np.float64(-0.008490548790190556)]
# bias:  0.26000000000000006
# Misclassified points count 22
# Epoch:  73 weights:  [np.float64(-0.18768591833791498), np.float64(-0.20402376228732078), np.float64(-0.19960978062590973), np.float64(-0.006949686713155876)]
# bias:  0.26000000000000006
# Misclassified points count 22
# Epoch:  74 weights:  [np.float64(-0.18396155312290663), np.float64(-0.20475618959239808), np.float64(-0.20662451625145153), np.float64(0.0001975618477090095)]
# bias:  0.26000000000000006
# Misclassified points count 24
# Epoch:  75 weights:  [np.float64(-0.18472809070520696), np.float64(-0.20269420199291147), np.float64(-0.21022319146825974), np.float64(-0.005026297374456014)]
# bias:  0.26000000000000006
# Misclassified points count 18
# Epoch:  76 weights:  [np.float64(-0.18969287735543167), np.float64(-0.20724084236679777), np.float64(-0.20529068554942856), np.float64(-0.0002054521458324382)]
# bias:  0.26000000000000006
# Misclassified points count 22
# Epoch:  77 weights:  [np.float64(-0.18969527154591406), np.float64(-0.20639763364976815), np.float64(-0.208245598933965), np.float64(-0.0017655373239107847)]
# bias:  0.26000000000000006
# Misclassified points count 18
# Epoch:  78 weights:  [np.float64(-0.19005917407640038), np.float64(-0.20770311135391445), np.float64(-0.20966230620949142), np.float64(-0.0007088985819254812)]
# bias:  0.26000000000000006
# Misclassified points count 22
# Epoch:  79 weights:  [np.float64(-0.18202126365662383), np.float64(-0.20040615872207945), np.float64(-0.21532204565154728), np.float64(0.0038663370618242255)]
# bias:  0.2700000000000001
# Misclassified points count 19
# Epoch:  80 weights:  [np.float64(-0.18817206664791966), np.float64(-0.20419399506823105), np.float64(-0.21225954538201952), np.float64(-0.0016165664810222184)]
# bias:  0.2700000000000001
# Misclassified points count 24
# Epoch:  81 weights:  [np.float64(-0.1910718928527672), np.float64(-0.2064580017736384), np.float64(-0.21026277971598395), np.float64(-0.002736131230402103)]
# bias:  0.2700000000000001
# Misclassified points count 20
# Epoch:  82 weights:  [np.float64(-0.1926805508801562), np.float64(-0.2035016879515936), np.float64(-0.2138430149167499), np.float64(-0.008353391491552474)]
# bias:  0.2700000000000001
# Misclassified points count 16
# Epoch:  83 weights:  [np.float64(-0.19398813945438698), np.float64(-0.2064826942865571), np.float64(-0.212221216368319), np.float64(-0.00878302316656535)]
# bias:  0.2700000000000001
# Misclassified points count 20
# Epoch:  84 weights:  [np.float64(-0.19564050588091347), np.float64(-0.2107660950356768), np.float64(-0.20921857283935877), np.float64(-0.00629444451724631)]
# bias:  0.2700000000000001
# Misclassified points count 18
# Epoch:  85 weights:  [np.float64(-0.19191614066590512), np.float64(-0.21149852234075409), np.float64(-0.21623330846490058), np.float64(0.0008528040436185762)]
# bias:  0.2700000000000001
# Misclassified points count 24
# Epoch:  86 weights:  [np.float64(-0.19253376248476878), np.float64(-0.20797312822968828), np.float64(-0.2210491282391872), np.float64(-0.008171607432021433)]
# bias:  0.2700000000000001
# Misclassified points count 18
# Epoch:  87 weights:  [np.float64(-0.1964230023292907), np.float64(-0.21310510726032283), np.float64(-0.21787319772130564), np.float64(-0.003811816165114522)]
# bias:  0.2700000000000001
# Misclassified points count 26
# Epoch:  88 weights:  [np.float64(-0.1939138979151823), np.float64(-0.21668002110407034), np.float64(-0.21940996347359012), np.float64(-0.0020652443487622057)]
# bias:  0.2700000000000001
# Misclassified points count 16
# Epoch:  89 weights:  [np.float64(-0.19193972199987322), np.float64(-0.21628047312036983), np.float64(-0.22494522849491516), np.float64(-0.0014515007254177975)]
# bias:  0.2700000000000001
# Misclassified points count 18
# Epoch:  90 weights:  [np.float64(-0.1896428712257276), np.float64(-0.21521040685208614), np.float64(-0.2209397689391833), np.float64(0.003063180792811245)]
# bias:  0.2800000000000001
# Misclassified points count 25
# Epoch:  91 weights:  [np.float64(-0.19814003353309265), np.float64(-0.21456845016033652), np.float64(-0.2190316671482248), np.float64(-0.006237160855524975)]
# bias:  0.2800000000000001
# Misclassified points count 22
# Epoch:  92 weights:  [np.float64(-0.20325671426202271), np.float64(-0.2148858344527701), np.float64(-0.21681466490144086), np.float64(-0.009247288622642494)]
# bias:  0.2800000000000001
# Misclassified points count 18
# Epoch:  93 weights:  [np.float64(-0.19953234904701436), np.float64(-0.2156182617578474), np.float64(-0.22382940052698266), np.float64(-0.0021000400617776065)]
# bias:  0.2800000000000001
# Misclassified points count 24
# Epoch:  94 weights:  [np.float64(-0.20216965082318644), np.float64(-0.21588384004310407), np.float64(-0.22269870324770438), np.float64(-0.006032456404736378)]
# bias:  0.2800000000000001
# Misclassified points count 18
# Epoch:  95 weights:  [np.float64(-0.20382201724971294), np.float64(-0.2201672407922238), np.float64(-0.21969605971874415), np.float64(-0.0035438777554173398)]
# bias:  0.2800000000000001
# Misclassified points count 18
# Epoch:  96 weights:  [np.float64(-0.2027205598223139), np.float64(-0.2216670705377401), np.float64(-0.22081563951407548), np.float64(-0.0045108988627323605)]
# bias:  0.2800000000000001
# Misclassified points count 16
# Epoch:  97 weights:  [np.float64(-0.2019366932046849), np.float64(-0.22475573383424105), np.float64(-0.22165516911254368), np.float64(-0.0010213963588712677)]
# bias:  0.2800000000000001
# Misclassified points count 20
# Epoch:  98 weights:  [np.float64(-0.2019390873951673), np.float64(-0.22391252511721144), np.float64(-0.22461008249708012), np.float64(-0.0025814815369496168)]
# bias:  0.2800000000000001
# Misclassified points count 18
# Epoch:  99 weights:  [np.float64(-0.20243606941710446), np.float64(-0.22049946154680652), np.float64(-0.23191711566409678), np.float64(-0.0025911600131044354)]
# bias:  0.2800000000000001
# Misclassified points count 24
# Epoch:  100 weights:  [np.float64(-0.20013921864295886), np.float64(-0.21942939527852284), np.float64(-0.22791165610836492), np.float64(0.0019235215051246072)]
# bias:  0.2900000000000001
# Misclassified points count 25
# Learning_rate:  0.01
# Final weights:  [np.float64(-0.15552388212217685), np.float64(-0.18197352673743716), np.float64(-0.1774085317417544), np.float64(0.0010315975101792031)]
# Final bias:  0.22000000000000006
# Final misclassified points count 16
# Final Misclassified points [156, 179, 200, 316, 357, 438, 446, 456, 690, 698, 780, 789, 868, 874, 968, 1010]
# Learning rate:  0.1
#
#
# Epoch:  1 weights:  [np.float64(-0.7529561336708276), np.float64(-0.5477985122377429), np.float64(-0.6564071207096562), np.float64(0.1907779304535031)]
# bias:  0.7999999999999999
# Misclassified points count 192
# Epoch:  2 weights:  [np.float64(-0.8282198999055305), np.float64(-0.7188328924178761), np.float64(-0.8476376985342), np.float64(0.16992768849159923)]
# bias:  0.9999999999999999
# Misclassified points count 78
# Epoch:  3 weights:  [np.float64(-0.8916204436463813), np.float64(-0.7808857723379499), np.float64(-0.9473968053405323), np.float64(0.046762209013899915)]
# bias:  1.0999999999999999
# Misclassified points count 43
# Epoch:  4 weights:  [np.float64(-0.946120944839871), np.float64(-0.8542270109673825), np.float64(-0.9696995217498178), np.float64(0.02555670519960679)]
# bias:  1.2
# Misclassified points count 39
# Epoch:  5 weights:  [np.float64(-0.976246655705313), np.float64(-0.968156596706418), np.float64(-1.0317536472506004), np.float64(0.11028544016473993)]
# bias:  1.3
# Misclassified points count 53
# Epoch:  6 weights:  [np.float64(-1.0028219191023238), np.float64(-1.0029761306955738), np.float64(-1.1339770319164073), np.float64(0.14480722984040795)]
# bias:  1.4000000000000001
# Misclassified points count 53
# Epoch:  7 weights:  [np.float64(-1.1262917429274037), np.float64(-1.01757180436076), np.float64(-1.2044422153893912), np.float64(0.03358939860532577)]
# bias:  1.4000000000000001
# Misclassified points count 36
# Epoch:  8 weights:  [np.float64(-1.1551538909201065), np.float64(-1.1213583987846447), np.float64(-1.1686887665112728), np.float64(0.08627809987363673)]
# bias:  1.5000000000000002
# Misclassified points count 45
# Epoch:  9 weights:  [np.float64(-1.1731994526534428), np.float64(-1.1680719110036772), np.float64(-1.2253271291620458), np.float64(0.04339532737398773)]
# bias:  1.5000000000000002
# Misclassified points count 26
# Epoch:  10 weights:  [np.float64(-1.213179658755744), np.float64(-1.181296474796722), np.float64(-1.2370069990986954), np.float64(0.047536810970187436)]
# bias:  1.6000000000000003
# Misclassified points count 41
# Epoch:  11 weights:  [np.float64(-1.1990858814875731), np.float64(-1.225772356658819), np.float64(-1.2981824854347115), np.float64(0.022579287686619293)]
# bias:  1.6000000000000003
# Misclassified points count 26
# Epoch:  12 weights:  [np.float64(-1.1710566896710897), np.float64(-1.2763961092173133), np.float64(-1.3744264749640935), np.float64(0.025544261711985483)]
# bias:  1.6000000000000003
# Misclassified points count 24
# Epoch:  13 weights:  [np.float64(-1.2469661359063697), np.float64(-1.2744065265466002), np.float64(-1.3250462164761219), np.float64(-0.05012719427154056)]
# bias:  1.7000000000000004
# Misclassified points count 31
# Epoch:  14 weights:  [np.float64(-1.2005504986694966), np.float64(-1.3170935726125987), np.float64(-1.4415628387964754), np.float64(-0.034380360368793335)]
# bias:  1.7000000000000004
# Misclassified points count 26
# Epoch:  15 weights:  [np.float64(-1.2827256567798169), np.float64(-1.3401366376423274), np.float64(-1.355050270174689), np.float64(-0.07662148921233718)]
# bias:  1.8000000000000005
# Misclassified points count 33
# Epoch:  16 weights:  [np.float64(-1.2354694567639517), np.float64(-1.3882282757149713), np.float64(-1.4340805737277118), np.float64(-0.07049650208265125)]
# bias:  1.8000000000000005
# Misclassified points count 24
# ...
# bias:  2.0000000000000004
# Misclassified points count 26
# Epoch:  28 weights:  [np.float64(-1.4199845538656866), np.float64(-1.6219964938801865), np.float64(-1.687078844437144), np.float64(-0.005762791220106624)]
# bias:  2.0000000000000004
# Misclassified points count 28
# Epoch:  29 weights:  [np.float64(-1.4528676567942433), np.float64(-1.626990746388166), np.float64(-1.6334629021894105), np.float64(-0.029256103336922287)]
# bias:  2.1000000000000005
# Misclassified points count 33
# Epoch:  30 weights:  [np.float64(-1.4723487953327778), np.float64(-1.6069053422489241), np.float64(-1.7080328004588257), np.float64(-0.0853314531754584)]
# bias:  2.1000000000000005
# Misclassified points count 22
# Epoch:  31 weights:  [np.float64(-1.5260643337732376), np.float64(-1.6841791376516788), np.float64(-1.6547790604906507), np.float64(-0.00956227640754529)]
# bias:  2.1000000000000005
# Misclassified points count 28
# Epoch:  32 weights:  [np.float64(-1.4805791856867874), np.float64(-1.7003699648639583), np.float64(-1.7103085209606208), np.float64(0.01499665091028124)]
# bias:  2.1000000000000005
# Misclassified points count 20
# Epoch:  33 weights:  [np.float64(-1.459773886737491), np.float64(-1.7498471526340735), np.float64(-1.719705468611847), np.float64(0.012297563532549197)]
# bias:  2.1000000000000005
# Misclassified points count 20
# Epoch:  34 weights:  [np.float64(-1.448035863098466), np.float64(-1.6491656856765395), np.float64(-1.7628896919620132), np.float64(0.03903468151822802)]
# bias:  2.2000000000000006
# Misclassified points count 27
# Epoch:  35 weights:  [np.float64(-1.5394247604006752), np.float64(-1.7172184945013345), np.float64(-1.7001512029565915), np.float64(-0.08365873356109998)]
# bias:  2.2000000000000006
# Misclassified points count 28
# Epoch:  36 weights:  [np.float64(-1.5088146023985263), np.float64(-1.7249459900391706), np.float64(-1.7433759632924444), np.float64(-0.07297072869378125)]
# bias:  2.2000000000000006
# Misclassified points count 18
# Epoch:  37 weights:  [np.float64(-1.5097789130952215), np.float64(-1.7536413542528009), np.float64(-1.7359044793368965), np.float64(-0.061169605466374545)]
# bias:  2.2000000000000006
# Misclassified points count 18
# Epoch:  38 weights:  [np.float64(-1.5069067498864295), np.float64(-1.7673696655154156), np.float64(-1.7590910314075165), np.float64(-0.041428200496093325)]
# bias:  2.2000000000000006
# Misclassified points count 22
# Epoch:  39 weights:  [np.float64(-1.4938686519698081), np.float64(-1.7799054470209141), np.float64(-1.800028470763754), np.float64(0.0005718275845918164)]
# bias:  2.2000000000000006
# Misclassified points count 20
# Epoch:  40 weights:  [np.float64(-1.5357519856637125), np.float64(-1.8083141850048765), np.float64(-1.7864859263347859), np.float64(0.008706268544951198)]
# bias:  2.2000000000000006
# Misclassified points count 24
# Epoch:  41 weights:  [np.float64(-1.555238821221768), np.float64(-1.8197352673743699), np.float64(-1.774085317417511), np.float64(0.010315975101791164)]
# bias:  2.2000000000000006
# Misclassified points count 16
# Epoch:  42 weights:  [np.float64(-1.5038726903633934), np.float64(-1.7232507904672392), np.float64(-1.8347398603629974), np.float64(0.049689242289510535)]
# bias:  2.3000000000000007
# Misclassified points count 25
# Epoch:  43 weights:  [np.float64(-1.5644497263267312), np.float64(-1.7747957993915677), np.float64(-1.7925316296299236), np.float64(-0.07252117564468709)]
# bias:  2.3000000000000007
# Misclassified points count 24
# Epoch:  44 weights:  [np.float64(-1.5686317713403968), np.float64(-1.8058990484458133), np.float64(-1.810327193848702), np.float64(-0.06375716572284504)]
# bias:  2.3000000000000007
# Misclassified points count 22
# Epoch:  45 weights:  [np.float64(-1.5760373919188972), np.float64(-1.8431807765849504), np.float64(-1.8396365557361727), np.float64(-0.05105964150325411)]
# bias:  2.3000000000000007
# Misclassified points count 26
# Epoch:  46 weights:  [np.float64(-1.5731652287101052), np.float64(-1.8569090878475651), np.float64(-1.8628231078067927), np.float64(-0.03131823653297288)]
# bias:  2.3000000000000007
# Misclassified points count 22
# Epoch:  47 weights:  [np.float64(-1.5741295394068002), np.float64(-1.8856044520611954), np.float64(-1.8553516238512449), np.float64(-0.01951711330556616)]
# bias:  2.3000000000000007
# Misclassified points count 18
# Epoch:  48 weights:  [np.float64(-1.5936163749648555), np.float64(-1.8970255344306888), np.float64(-1.84295101493397), np.float64(-0.017907406748726193)]
# bias:  2.3000000000000007
# Misclassified points count 16
# Epoch:  49 weights:  [np.float64(-1.609522741925027), np.float64(-1.8996738335696874), np.float64(-1.8495540586578523), np.float64(-0.013307884120374092)]
# bias:  2.3000000000000007
# Misclassified points count 18
# Epoch:  50 weights:  [np.float64(-1.5619303456432339), np.float64(-1.8027867328725795), np.float64(-1.9104082678200733), np.float64(0.024891301539755994)]
# bias:  2.400000000000001
# Misclassified points count 25
# Epoch:  51 weights:  [np.float64(-1.653161312910612), np.float64(-1.8431351708344654), np.float64(-1.860472997623813), np.float64(-0.11828238685824097)]
# bias:  2.400000000000001
# Misclassified points count 26
# Epoch:  52 weights:  [np.float64(-1.6500583843541212), np.float64(-1.822863848799045), np.float64(-1.8929084510989962), np.float64(-0.09969107315018648)]
# bias:  2.400000000000001
# Misclassified points count 16
# Epoch:  53 weights:  [np.float64(-1.6331585725721078), np.float64(-1.8293834729669496), np.float64(-1.9308422723136387), np.float64(-0.1089018842139765)]
# bias:  2.400000000000001
# Misclassified points count 20
# Epoch:  54 weights:  [np.float64(-1.6712883636573541), np.float64(-1.8674862393216702), np.float64(-1.8908540884137213), np.float64(-0.0933003210558355)]
# bias:  2.400000000000001
# Misclassified points count 20
# Epoch:  55 weights:  [np.float64(-1.6648984711795833), np.float64(-1.8878114440947829), np.float64(-1.9021865908825957), np.float64(-0.07733530022932736)]
# bias:  2.400000000000001
# Misclassified points count 20
# Epoch:  56 weights:  [np.float64(-1.6585085787018126), np.float64(-1.9081366488678957), np.float64(-1.91351909335147), np.float64(-0.06137027940281923)]
# bias:  2.400000000000001
# Misclassified points count 20
# Epoch:  57 weights:  [np.float64(-1.6556364154930205), np.float64(-1.9218649601305104), np.float64(-1.9367056454220901), np.float64(-0.04162887443253801)]
# bias:  2.400000000000001
# Misclassified points count 22
# Epoch:  58 weights:  [np.float64(-1.699898074551642), np.float64(-1.9706997833464865), np.float64(-1.886641001867255), np.float64(-0.007689687836385101)]
# bias:  2.400000000000001
# Misclassified points count 22
# Epoch:  59 weights:  [np.float64(-1.6999220164564657), np.float64(-1.962267696176191), np.float64(-1.916190135712619), np.float64(-0.023290539617168572)]
# bias:  2.400000000000001
# Misclassified points count 18
# Epoch:  60 weights:  [np.float64(-1.6523296201746724), np.float64(-1.8653805954790827), np.float64(-1.97704434487484), np.float64(0.014908646042961493)]
# bias:  2.500000000000001
# Misclassified points count 25
# Epoch:  61 weights:  [np.float64(-1.7014322314288104), np.float64(-1.9141690196709347), np.float64(-1.944945650252028), np.float64(0.02959091309027745)]
# bias:  2.500000000000001
# Misclassified points count 24
# Epoch:  62 weights:  [np.float64(-1.728832948243672), np.float64(-1.905295153921272), np.float64(-2.0060843083053035), np.float64(-0.0854409678476175)]
# bias:  2.500000000000001
# Misclassified points count 26
# Epoch:  63 weights:  [np.float64(-1.7382665635434147), np.float64(-1.9687326854931884), np.float64(-1.9772187832866517), np.float64(-0.06896780830252464)]
# bias:  2.500000000000001
# Misclassified points count 22
# Epoch:  64 weights:  [np.float64(-1.7353944003346224), np.float64(-1.9824609967558033), np.float64(-2.000405335357272), np.float64(-0.04922640333224341)]
# bias:  2.500000000000001
# Misclassified points count 22
# Epoch:  65 weights:  [np.float64(-1.7592722677743529), np.float64(-2.0336651636875183), np.float64(-1.9515749136432476), np.float64(-0.028504514438154445)]
# bias:  2.500000000000001
# Misclassified points count 16
# Epoch:  66 weights:  [np.float64(-1.7575693637366803), np.float64(-2.0119305511380787), np.float64(-2.001565469388072), np.float64(-0.02703942340993338)]
# bias:  2.500000000000001
# Misclassified points count 20
# Epoch:  67 weights:  [np.float64(-1.7697019961202698), np.float64(-2.0149814740670546), np.float64(-2.0079688468952197), np.float64(-0.021265819253991992)]
# bias:  2.500000000000001
# Misclassified points count 18
# Epoch:  68 weights:  [np.float64(-1.7818346285038595), np.float64(-2.0180323969960305), np.float64(-2.014372224402368), np.float64(-0.015492215098050606)]
# bias:  2.500000000000001
# Misclassified points count 18
# Epoch:  69 weights:  [np.float64(-1.734483237782069), np.float64(-1.9671379435503416), np.float64(-2.1317391315597334), np.float64(-0.04687687368372012)]
# bias:  2.500000000000001
# Misclassified points count 16
# Epoch:  70 weights:  [np.float64(-1.773398207962859), np.float64(-2.0069132076318836), np.float64(-1.9934293513650696), np.float64(-0.005615582908225239)]
# bias:  2.600000000000001
# Misclassified points count 23
# Epoch:  71 weights:  [np.float64(-1.802082052225095), np.float64(-1.9694448356763519), np.float64(-2.0544394985488275), np.float64(-0.11252652033509851)]
# bias:  2.600000000000001
# Misclassified points count 22
# Epoch:  72 weights:  [np.float64(-1.8466480330859942), np.float64(-2.0266726436592295), np.float64(-1.9958612255106671), np.float64(-0.08490548790190723)]
# bias:  2.600000000000001
# Misclassified points count 22
# Epoch:  73 weights:  [np.float64(-1.8768591833791384), np.float64(-2.040237622873215), np.float64(-1.9960978062590486), np.float64(-0.06949686713156047)]
# bias:  2.600000000000001
# Misclassified points count 22
# Epoch:  74 weights:  [np.float64(-1.8396155312290545), np.float64(-2.0475618959239883), np.float64(-2.0662451625144658), np.float64(0.0019756184770883672)]
# bias:  2.600000000000001
# Misclassified points count 24
# Epoch:  75 weights:  [np.float64(-1.8472809070520577), np.float64(-2.0269420199291224), np.float64(-2.1022319146825477), np.float64(-0.05026297374456189)]
# bias:  2.600000000000001
# Misclassified points count 18
# Epoch:  76 weights:  [np.float64(-1.8969287735543041), np.float64(-2.0724084236679863), np.float64(-2.0529068554942365), np.float64(-0.0020545214583261584)]
# bias:  2.600000000000001
# Misclassified points count 22
# Epoch:  77 weights:  [np.float64(-1.896952715459128), np.float64(-2.0639763364976904), np.float64(-2.082455989339601), np.float64(-0.01765537323910963)]
# bias:  2.600000000000001
# Misclassified points count 18
# Epoch:  78 weights:  [np.float64(-1.9005917407639905), np.float64(-2.0770311135391535), np.float64(-2.096623062094866), np.float64(-0.007088985819256627)]
# bias:  2.600000000000001
# Misclassified points count 22
# Epoch:  79 weights:  [np.float64(-1.8202126365662248), np.float64(-2.004061587220803), np.float64(-2.1532204565154243), np.float64(0.03866337061824046)]
# bias:  2.700000000000001
# Misclassified points count 19
# Epoch:  80 weights:  [np.float64(-1.8817206664791832), np.float64(-2.041939950682319), np.float64(-2.1225954538201464), np.float64(-0.016165664810224037)]
# bias:  2.700000000000001
# Misclassified points count 24
# Epoch:  81 weights:  [np.float64(-1.9107189285276582), np.float64(-2.064580017736392), np.float64(-2.10262779715979), np.float64(-0.027361312304022924)]
# bias:  2.700000000000001
# Misclassified points count 20
# Epoch:  82 weights:  [np.float64(-1.9268055088015479), np.float64(-2.0350168795159442), np.float64(-2.1384301491674487), np.float64(-0.0835339149155267)]
# bias:  2.700000000000001
# Misclassified points count 16
# Epoch:  83 weights:  [np.float64(-1.9398813945438553), np.float64(-2.06482694286558), np.float64(-2.1222121636831397), np.float64(-0.08783023166565546)]
# bias:  2.700000000000001
# Misclassified points count 20
# Epoch:  84 weights:  [np.float64(-1.9564050588091202), np.float64(-2.1076609503567774), np.float64(-2.0921857283935377), np.float64(-0.06294444517246506)]
# bias:  2.700000000000001
# Misclassified points count 18
# Epoch:  85 weights:  [np.float64(-1.9191614066590363), np.float64(-2.1149852234075492), np.float64(-2.162333084648955), np.float64(0.00852804043618377)]
# bias:  2.700000000000001
# Misclassified points count 24
# Epoch:  86 weights:  [np.float64(-1.9253376248476728), np.float64(-2.079731282296891), np.float64(-2.210491282391821), np.float64(-0.08171607432021635)]
# bias:  2.700000000000001
# Misclassified points count 18
# Epoch:  87 weights:  [np.float64(-1.9642300232928918), np.float64(-2.1310510726032357), np.float64(-2.178731977213006), np.float64(-0.03811816165114726)]
# bias:  2.700000000000001
# Misclassified points count 26
# Epoch:  88 weights:  [np.float64(-1.939138979151808), np.float64(-2.1668002110407105), np.float64(-2.194099634735851), np.float64(-0.0206524434876241)]
# bias:  2.700000000000001
# Misclassified points count 16
# Epoch:  89 weights:  [np.float64(-1.9193972199987173), np.float64(-2.1628047312037055), np.float64(-2.2494522849491014), np.float64(-0.014515007254179993)]
# bias:  2.700000000000001
# Misclassified points count 18
# Epoch:  90 weights:  [np.float64(-1.8964287122572612), np.float64(-2.1521040685208686), np.float64(-2.2093976893917833), np.float64(0.030631807928110405)]
# bias:  2.800000000000001
# Misclassified points count 25
# Epoch:  91 weights:  [np.float64(-1.9814003353309124), np.float64(-2.145684501603372), np.float64(-2.190316671482198), np.float64(-0.062371608555251846)]
# bias:  2.800000000000001
# Misclassified points count 22
# Epoch:  92 weights:  [np.float64(-2.0325671426202128), np.float64(-2.148858344527708), np.float64(-2.168146649014358), np.float64(-0.09247288622642708)]
# bias:  2.800000000000001
# Misclassified points count 18
# Epoch:  93 weights:  [np.float64(-1.9953234904701296), np.float64(-2.15618261757848), np.float64(-2.238294005269775), np.float64(-0.02100040061777826)]
# bias:  2.800000000000001
# Misclassified points count 24
# Epoch:  94 weights:  [np.float64(-2.0216965082318494), np.float64(-2.158838400431047), np.float64(-2.2269870324769925), np.float64(-0.06032456404736599)]
# bias:  2.800000000000001
# Misclassified points count 18
# Epoch:  95 weights:  [np.float64(-2.038220172497114), np.float64(-2.2016724079222434), np.float64(-2.1969605971873905), np.float64(-0.035438777554175606)]
# bias:  2.800000000000001
# Misclassified points count 18
# Epoch:  96 weights:  [np.float64(-2.027205598223123), np.float64(-2.216670705377406), np.float64(-2.208156395140704), np.float64(-0.045108988627325826)]
# bias:  2.800000000000001
# Misclassified points count 16
# Epoch:  97 weights:  [np.float64(-2.019366932046833), np.float64(-2.2475573383424154), np.float64(-2.2165516911253866), np.float64(-0.010213963588714924)]
# bias:  2.800000000000001
# Misclassified points count 20
# Epoch:  98 weights:  [np.float64(-2.019390873951656), np.float64(-2.239125251172119), np.float64(-2.246100824970751), np.float64(-0.025814815369498402)]
# bias:  2.800000000000001
# Misclassified points count 18
# Epoch:  99 weights:  [np.float64(-2.024360694171027), np.float64(-2.20499461546807), np.float64(-2.3191711566409188), np.float64(-0.025911600131046625)]
# bias:  2.800000000000001
# Misclassified points count 24
# Epoch:  100 weights:  [np.float64(-2.0013921864295705), np.float64(-2.194293952785233), np.float64(-2.2791165610836006), np.float64(0.019235215051243773)]
# bias:  2.9000000000000012
# Misclassified points count 25
# Learning_rate:  0.1
# Final weights:  [np.float64(-1.555238821221768), np.float64(-1.8197352673743699), np.float64(-1.774085317417511), np.float64(0.010315975101791164)]
# Final bias:  2.2000000000000006
# Final misclassified points count 16
# Final Misclassified points [156, 179, 200, 316, 357, 438, 446, 456, 690, 698, 780, 789, 868, 874, 968, 1010]

# %%
print(len(weight1_histories))
print(len(mis_classified_count))
# Out:
# 3
# 100

# %%
#Plotting numer of epochs vs missclassified points
for i in range(len(mis_classified_list)):
  plt.figure(figsize=(12,8))
  plt.plot(mis_classified_list[i])
  plt.title(lr[i])
  plt.show()

# %%
#Lisiting best parameters
print("Best learning rate:",best_lr)
print("Best weights:",best_weights)
print("Best bias:",best_bias)
print("Minimum Misclassified Samples:",best_misclassified)
print("Misclassified Points:",best_misclassified_pts)
# Out:
# Best learning rate: 0.001
# Best weights: [np.float64(-0.015552388212217485), np.float64(-0.01819735267374384), np.float64(-0.01774085317417528), np.float64(0.00010315975101792289)]
# Best bias: 0.022000000000000013
# Minimum Misclassified Samples: 16
# Misclassified Points: [156, 179, 200, 316, 357, 438, 446, 456, 690, 698, 780, 789, 868, 874, 968, 1010]

# %%
y_predicted=[]

# %%
#Model training with best possible parameters from our result
def final_train(x_train,y_train,w1,w2,w3,w4,b,lr):
  w1=best_weights[0]
  w2=best_weights[1]
  w3=best_weights[2]
  w4=best_weights[3]
  b=best_bias
  for i in range(x_val.shape[0]):
    y_predicted.append(forward_prop(x_val[i],w1,w2,w3,w4,b))

# %%
final_train(x_val,y_val,w1,w2,w3,w4,b,best_lr)

# %%
#Final test evaluation metrics
print("Accuracy_score: ",accuracy_score(y_val,y_predicted))
print("Precision_score: ",precision_score(y_val,y_predicted))
print("Recall_score: ",recall_score(y_val,y_predicted))
print("F1_score: ",f1_score(y_val,y_predicted))
# Out:
# Accuracy_score:  0.9890909090909091
# Precision_score:  0.9917355371900827
# Recall_score:  0.9836065573770492
# F1_score:  0.9876543209876543

# %%
#Confusion matrix
plt.figure(figsize=(12,8))
sns.heatmap(confusion_matrix(y_val,y_predicted),annot=True,fmt="g")
plt.show()

# %%
#Weight and bias progress for all features with different learning rate
for i in range(len(weight1_histories)):
    plt.figure(figsize=(15,5))
    plt.plot(weight1_histories[i],marker='o')
    plt.title(f"Weight 1 (Learning Rate={lr[i]})")
    plt.grid(True)
    plt.show()

for i in range(len(weight2_histories)):
    plt.figure(figsize=(15,5))
    plt.plot(weight2_histories[i],marker='o')
    plt.title(f"Weight 2 (Learning Rate={lr[i]})")
    plt.grid(True)
    plt.show()

for i in range(len(weight3_histories)):
    plt.figure(figsize=(15,5))
    plt.plot(weight3_histories[i],marker='o')
    plt.title(f"Weight 3 (Learning Rate={lr[i]})")
    plt.grid(True)
    plt.show()


for i in range(len(weight4_histories)):
    plt.figure(figsize=(15,5))
    plt.plot(weight4_histories[i],marker='o')
    plt.title(f"Weight 4 (Learning Rate={lr[i]})")
    plt.grid(True)
    plt.show()


for i in range(len(bias_histories)):
    plt.figure(figsize=(15,5))
    plt.plot(bias_histories[i],marker='o')
    plt.title(f"bias (Learning Rate={lr[i]})")
    plt.grid(True)
    plt.show()

# %%
#Learning rate comparison
plt.figure(figsize=(8,5))

for i in range(len(lr)):
    plt.plot(mis_classified_list[i],label=f"LR={lr[i]}")

plt.xlabel("Epoch")
plt.ylabel("Misclassified Samples")
plt.title("Learning Rate Comparison")
plt.legend()
plt.grid(True)
plt.show()
